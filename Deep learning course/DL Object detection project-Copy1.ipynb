# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
import os
os.path.exists(r"C:\Users\nisarg\Documents\models\research\object_detection")
# Out:
# False

# %%
import os
os.listdir(r"C:\Users\nisarg\Documents\models")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26756/3941243292.py in <module>
#       1 import os
# ----> 2 os.listdir(r"C:\Users\nisarg\Documents\models")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\nisarg\\Documents\\models'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nisarg'

# %%
import os
os.path.exists(r"C:\Users\nisarg\models")
# Out:
# True

# %%
import os
os.listdir(r"C:\Users\nisarg\models")
# Out:
# ['.git']

# %%
# !rmdir /s /q C:\Users\nisarg\models
# Out:
# C:\Users\nisarg\models\GIT~1\objects\pack\tmp_pack_2TCgIw - The process cannot access the file because it is being used by another process.

# %%
# !taskkill /F /IM git.exe
# Out:
# SUCCESS: The process "git.exe" with PID 12128 has been terminated.
# SUCCESS: The process "git.exe" with PID 18280 has been terminated.
# SUCCESS: The process "git.exe" with PID 13360 has been terminated.
# SUCCESS: The process "git.exe" with PID 23448 has been terminated.

# %%
# !rmdir /s /q C:\Users\nisarg\models

# %%
# %cd C:\Users\nisarg\Documents
# Out:
# C:\Users\nisarg\Documents

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# fatal: could not create work tree dir 'models': No such file or directory

# %%
import os
print("Exists:", os.path.exists(r"C:\Users\nisarg\Documents"))
print("Writable:", os.access(r"C:\Users\nisarg\Documents", os.W_OK))
print("Contents sample:", os.listdir(r"C:\Users\nisarg\Documents")[:10])
# Out:
# Exists: True
# Writable: True
# Contents sample: ['Custom Office Templates', 'CyberLink', 'Default.rdp', 'desktop.ini', 'GitHub', 'IISExpress', 'My Digital Editions', 'My Music', 'My Pictures', 'My Videos']

# %%
# %cd C:\Users\nisarg\Documents\GitHub
# Out:
# C:\Users\nisarg\Documents\GitHub

# %%
# !git clone https://github.com/tensorflow/models.git tf-models
# Out:
# fatal: could not create work tree dir 'tf-models': No such file or directory

# %%
# !git clone https://github.com/tensorflow/models.git tf-models
# Out:
# ^C

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 46C8-E9DC
#
#  Directory of C:\Users\nisarg\Documents\GitHub
#
# 2026-01-13  05:21 PM    <DIR>          .
# 2026-01-04  03:59 PM    <DIR>          ..
# 2026-01-04  03:59 PM    <DIR>          Sentiment-Analysis-of-Twitter-products
# 2026-01-13  05:21 PM    <DIR>          tf-models
#                0 File(s)              0 bytes
#                4 Dir(s)  19,019,038,720 bytes free

# %%
import os
os.path.exists(r"C:\Users\nisarg\Documents\GitHub\tf-models\research\object_detection")
# Out:
# False

# %%
import os
os.listdir(r"C:\Users\nisarg\Documents\GitHub\tf-models")[:30]
# Out:
# ['.git']
# Cloning into 'tf-models'...
# Updating files:  30% (1207/3962)
# Updating files:  31% (1229/3962)
# Updating files:  32% (1268/3962)
# Updating files:  33% (1308/3962)
# Updating files:  34% (1348/3962)
# Updating files:  35% (1387/3962)
# Updating files:  36% (1427/3962)
# Updating files:  37% (1466/3962)
# Updating files:  38% (1506/3962)
# Updating files:  39% (1546/3962)
# Updating files:  40% (1585/3962)
# Updating files:  41% (1625/3962)
# Updating files:  42% (1665/3962)
# Updating files:  43% (1704/3962)
# Updating files:  44% (1744/3962)
# Updating files:  45% (1783/3962)
# Updating files:  46% (1823/3962)
# Updating files:  47% (1863/3962)
# Updating files:  48% (1902/3962)
# Updating files:  49% (1942/3962)
# Updating files:  50% (1981/3962)
# Updating files:  51% (2021/3962)
# Updating files:  52% (2061/3962)
# Updating files:  53% (2100/3962)
# Updating files:  54% (2140/3962)
# Updating files:  54% (2157/3962)
# Updating files:  55% (2180/3962)
# ...

# %%
import os
os.path.exists(r"C:\Users\nisarg\Documents\GitHub\tf-models\research\object_detection")
# Out:
# True

# %%
# %cd C:\Users\nisarg\Documents\GitHub\tf-models\research
# Out:
# C:\Users\nisarg\Documents\GitHub\tf-models\research

# %%
# !python -m pip install grpcio-tools protobuf==3.20.*
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.8.0 requires google-auth-oauthlib<0.5,>=0.4.1, but you have google-auth-oauthlib 1.2.3 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# ...

# %%
# !python -m grpc_tools.protoc object_detection/protos/*.proto --python_out=.
# Out:
# object_detection/protos/anchor_generator.proto: File does not reside within any path specified using --proto_path (or -I).  You must specify a --proto_path which encompasses this file.  Note that the proto_path must be an exact prefix of the .proto file names -- protoc is too dumb to figure out when two paths (e.g. absolute and relative) are equivalent (it's harder than you think).

# %%
# !python -m grpc_tools.protoc -I. -Iobject_detection/protos object_detection/protos/*.proto --python_out=.
# Out:
# ./object_detection/protos/anchor_generator_pb2.py: No such file or directory

# %%
# !python -m grpc_tools.protoc -I. -Iobject_detection/protos object_detection/protos/*.proto --python_out=.

# %%
import os
os.path.exists(r"C:\Users\nisarg\Documents\GitHub\tf-models\research\object_detection\protos\anchor_generator_pb2.py")
# Out:
# True

# %%
import sys
sys.path.append(r"C:\Users\nisarg\Documents\GitHub\tf-models\research")
sys.path.append(r"C:\Users\nisarg\Documents\GitHub\tf-models\research\slim")

from object_detection.utils import ops as utils_ops
print("IMPORT OK")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26756/3697144869.py in <module>
#       3 sys.path.append(r"C:\Users\nisarg\Documents\GitHub\tf-models\research\slim")
#       4
# ----> 5 from object_detection.utils import ops as utils_ops
#       6 print("IMPORT OK")
#
# ~\Documents\GitHub\tf-models\research\object_detection\utils\ops.py in <module>
#      26 from six.moves import zip
#      27 import tensorflow.compat.v1 as tf
# ---> 28 import tf_slim as slim
#      29 from object_detection.core import standard_fields as fields
#      30 from object_detection.utils import shape_utils
#
# ModuleNotFoundError: No module named 'tf_slim'

# %%
# !python -m pip install tf_slim
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisarg\anaconda3\lib\site-packages)

# %%
import sys
sys.path.append(r"C:\Users\nisarg\Documents\GitHub\tf-models\research")
sys.path.append(r"C:\Users\nisarg\Documents\GitHub\tf-models\research\slim")

from object_detection.utils import ops as utils_ops
print("IMPORT OK")
# Out:
# IMPORT OK

# %%
# !powershell -Command "Get-WinEvent -LogName 'Microsoft-Windows-Windows Defender/Operational' -MaxEvents 5 | Select-Object TimeCreated,Id,Message | Format-List"
# Out:
# TimeCreated : 2026-01-13 5:32:17 PM
# Id          : 1123
# Message     : C:\Users\nisarg\anaconda3\python.exe has been blocked from modifying
#               %userprofile%\Documents\GitHub\tf-models\research\object_detection\core\__pycache__ by Controlled Folder Access.
#                	Detection time: 2026-01-13T22:32:17.581Z
#                	User: LAPTOP-FE360HF3\nisarg
#                	Path: %userprofile%\Documents\GitHub\tf-models\research\object_detection\core\__pycache__
#                	Process Name: C:\Users\nisarg\anaconda3\python.exe
#                	Security intelligence Version: 1.443.653.0
#                	Engine Version: 1.1.25110.1
#                	Product Version: 4.18.25110.6
#
#
# TimeCreated : 2026-01-13 5:30:36 PM
# Id          : 5007
# Message     : Microsoft Defender Antivirus Configuration has changed. If this is an unexpected event you should review the settings as this may be the
#               result of malware.
#                	Old value:
# ...

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\nisarg\\anaconda3\\python.exe'

# %%
# !mkdir C:\tf-models

# %%
# !robocopy "C:\Users\nisarg\Documents\GitHub\tf-models" "C:\tf-models" /E
# Out:
# -------------------------------------------------------------------------------
#    ROBOCOPY     ::     Robust File Copy for Windows
# -------------------------------------------------------------------------------
#
#   Started : January 13, 2026 5:34:36 PM
#    Source : C:\Users\nisarg\Documents\GitHub\tf-models\
#      Dest : C:\tf-models\
#
#     Files : *.*
#
#   Options : *.* /S /E /DCOPY:DA /COPY:DAT /R:1000000 /W:30
#
# ------------------------------------------------------------------------------
#
# 	                   9	C:\Users\nisarg\Documents\GitHub\tf-models\
# 	    New File  		    1202	.gitignore
# 100%
# 	    New File  		     347	AUTHORS
# 100%
# 	    New File  		    1247	CODEOWNERS
# 100%
# 	    New File  		    5489	CODE_OF_CONDUCT.md
# 100%
# 	    New File  		     400	CONTRIBUTING.md
# 100%
# 	    New File  		    1139	ISSUES.md
# 100%
# 	    New File  		   11724	LICENSE
# 100%
# 	    New File  		    5067	README.md
# 100%
# 	    New File  		   13685	SECURITY.md
# ...

# %%
import sys
sys.path = [p for p in sys.path if "tf-models" not in p]  # remove old paths if any

sys.path.append(r"C:\tf-models\research")
sys.path.append(r"C:\tf-models\research\slim")

from object_detection.utils import ops as utils_ops
print("IMPORT OK from C:\\tf-models")
# Out:
# IMPORT OK from C:\tf-models

# %%
import object_detection, inspect
print(object_detection.__file__)
# Out:
# C:\Users\nisarg\Documents\GitHub\tf-models\research\object_detection\__init__.py

# %%
import sys
sys.path.append(r"C:\tf-models\research")
sys.path.append(r"C:\tf-models\research\slim")

import object_detection
print(object_detection.__file__)
# Out:
# C:\tf-models\research\object_detection\__init__.py

# %%
# This is needed to display the images.
# %matplotlib inline

# %%
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util
print("utils imports OK")
# Out:
# utils imports OK

# %%
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util
print("utils imports OK")
# Out:
# utils imports OK

# %%
import sys
[p for p in sys.path if "tf-models" in p or "tf\\models" in p or "object_detection" in p][:20]
# Out:
# ['C:\\tf-models\\research', 'C:\\tf-models\\research\\slim']

# %%
# What model to download.
MODEL_NAME = 'ssd_mobilenet_v1_coco_2017_11_17'
MODEL_FILE = MODEL_NAME + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('data', 'mscoco_label_map.pbtxt')

NUM_CLASSES = 90

# %%
import os
print("os imported")
# Out:
# os imported

# %%
import os
print("CWD:", os.getcwd())
print("LABEL PATH:", os.path.abspath(PATH_TO_LABELS))
print("Exists:", os.path.exists(PATH_TO_LABELS))
# Out:
# CWD: C:\Users\nisarg
# LABEL PATH: C:\Users\nisarg\data\mscoco_label_map.pbtxt
# Exists: False

# %%
PATH_TO_LABELS = r"C:\tf-models\research\object_detection\data\mscoco_label_map.pbtxt"
import os
print("Exists:", os.path.exists(PATH_TO_LABELS))
# Out:
# Exists: True

# %%
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)
print("Num categories:", len(category_index))
# Out:
# Num categories: 80

# %%
import os
print("CKPT:", PATH_TO_CKPT)
print("Abs CKPT:", os.path.abspath(PATH_TO_CKPT))
print("Exists:", os.path.exists(PATH_TO_CKPT))
# Out:
# CKPT: ssd_mobilenet_v1_coco_2017_11_17/frozen_inference_graph.pb
# Abs CKPT: C:\Users\nisarg\ssd_mobilenet_v1_coco_2017_11_17\frozen_inference_graph.pb
# Exists: False

# %%
import os, glob
matches = glob.glob(r"C:\tf-models\research\object_detection\**\ssd_mobilenet_v1_coco_2017_11_17", recursive=True)
matches[:5], len(matches)
# Out:
# ([], 0)

# %%
# %cd C:\tf-models\research\object_detection
# Out:
# C:\tf-models\research\object_detection

# %%
# !powershell -Command "Invoke-WebRequest -Uri http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v1_coco_2017_11_17.tar.gz -OutFile ssd_mobilenet_v1_coco_2017_11_17.tar.gz"
# Out:
# ^C

# %%
import os
print(os.path.exists(r"C:\tf-models\research\object_detection\ssd_mobilenet_v1_coco_2017_11_17.tar.gz"))
if os.path.exists(r"C:\tf-models\research\object_detection\ssd_mobilenet_v1_coco_2017_11_17.tar.gz"):
    print("Size (MB):", os.path.getsize(r"C:\tf-models\research\object_detection\ssd_mobilenet_v1_coco_2017_11_17.tar.gz")/1024/1024)
# Out:
# True
# Size (MB): 66.9365873336792

# %%
# !python -c "import tarfile; tarfile.open('ssd_mobilenet_v1_coco_2017_11_17.tar.gz','r:gz').extractall('.')"
print("extracted")
# Out:
# extracted

# %%
import os
PATH_TO_CKPT = r"C:\tf-models\research\object_detection\ssd_mobilenet_v1_coco_2017_11_17\frozen_inference_graph.pb"
print("Exists:", os.path.exists(PATH_TO_CKPT))
# Out:
# Exists: True

# %%
import os

MODEL_NAME = 'ssd_mobilenet_v1_coco_2017_11_17'
PATH_TO_CKPT = r"C:\tf-models\research\object_detection\ssd_mobilenet_v1_coco_2017_11_17\frozen_inference_graph.pb"
PATH_TO_LABELS = r"C:\tf-models\research\object_detection\data\mscoco_label_map.pbtxt"
NUM_CLASSES = 90

print("CKPT exists:", os.path.exists(PATH_TO_CKPT))
print("LABEL exists:", os.path.exists(PATH_TO_LABELS))
# Out:
# CKPT exists: True
# LABEL exists: True

# %%
import tensorflow as tf

detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.compat.v1.GraphDef()
    with tf.io.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')

print("graph loaded")
# Out:
# graph loaded

# %%
import tensorflow as tf

sess = tf.compat.v1.Session(graph=detection_graph)

image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
num_detections = detection_graph.get_tensor_by_name('num_detections:0')

print("tensors ready")
# Out:
# tensors ready

# %%
import os
print("CWD:", os.getcwd())
print("Files here (first 30):", os.listdir(os.getcwd())[:30])
# Out:
# CWD: C:\tf-models\research\object_detection
# Files here (first 30): ['anchor_generators', 'box_coders', 'builders', 'colab_tutorials', 'configs', 'CONTRIBUTING.md', 'core', 'data', 'dataset_tools', 'data_decoders', 'dockerfiles', 'eval_util.py', 'eval_util_test.py', 'exporter.py', 'exporter_lib_tf2_test.py', 'exporter_lib_v2.py', 'exporter_main_v2.py', 'exporter_tf1_test.py', 'export_inference_graph.py', 'export_tflite_graph_lib_tf2.py', 'export_tflite_graph_lib_tf2_test.py', 'export_tflite_graph_tf2.py', 'export_tflite_ssd_graph.py', 'export_tflite_ssd_graph_lib.py', 'export_tflite_ssd_graph_lib_tf1_test.py', 'g3doc', 'inference', 'inputs.py', 'inputs_test.py', 'legacy']

# %%
import os
os.listdir(r"C:\tf-models\research\object_detection\inference")[:50]
# Out:
# ['detection_inference.py',
#  'detection_inference_tf1_test.py',
#  'infer_detections.py',
#  '__init__.py']

# %%
# !powershell -Command "Invoke-WebRequest -Uri https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/test_images/image1.jpg -OutFile image1.jpg"
print("downloaded image1.jpg")
# Out:
# downloaded image1.jpg

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

def load_image_into_numpy_array(image_path):
    image = Image.open(image_path)
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape((im_height, im_width, 3)).astype(np.uint8)

image_np = load_image_into_numpy_array("image1.jpg")
image_np_expanded = np.expand_dims(image_np, axis=0)

(boxes, scores, classes, num) = sess.run(
    [detection_boxes, detection_scores, detection_classes, num_detections],
    feed_dict={image_tensor: image_np_expanded}
)

vis_util.visualize_boxes_and_labels_on_image_array(
    image_np,
    np.squeeze(boxes),
    np.squeeze(classes).astype(np.int32),
    np.squeeze(scores),
    category_index,
    use_normalized_coordinates=True,
    line_thickness=6
)

plt.figure(figsize=(12,8))
plt.imshow(image_np)
plt.axis('off')
plt.show()
