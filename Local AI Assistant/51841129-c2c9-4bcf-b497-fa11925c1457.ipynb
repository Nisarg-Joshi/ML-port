# %%
import sys
print(sys.version)
# Out:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-4o-mini", api_key="sk-...")
print(llm)
# Out:
# callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x0000017EC3196BC0> rate_limiter=None system_prompt=None messages_to_prompt=<function messages_to_prompt at 0x0000017EDA05BB50> completion_to_prompt=<function default_completion_to_prompt at 0x0000017EDA428820> output_parser=None pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'> query_wrapper_prompt=None model='gpt-4o-mini' temperature=0.1 max_tokens=None logprobs=None top_logprobs=0 additional_kwargs={} max_retries=3 timeout=60.0 default_headers=None reuse_client=True api_key='sk-...' api_base='https://api.openai.com/v1' api_version='' strict=False reasoning_effort=None modalities=None audio_config=None

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-4o-mini", api_key="YOUR_REAL_API_KEY")

response = llm.complete("Say hello in one short sentence.")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[3], line 5
#       1 from llama_index.llms.openai import OpenAI
#       3 llm = OpenAI(model="gpt-4o-mini", api_key="YOUR_REAL_API_KEY")
# ----> 5 response = llm.complete("Say hello in one short sentence.")
#       6 print(response)
#
# File ~\anaconda3\envs\llamaindex310\lib\site-packages\llama_index_instrumentation\dispatcher.py:413, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     410             _logger.debug(f"Failed to reset active_span_id: {e}")
#     412 try:
# --> 413     result = func(*args, **kwargs)
#     414     if isinstance(result, asyncio.Future):
#     415         # If the result is a Future, wrap it
#     416         new_future = asyncio.ensure_future(result)
#
# ...

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-4o-mini", api_key="paste-your-actual-key-here")

response = llm.complete("Say hello in one short sentence.")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[4], line 5
#       1 from llama_index.llms.openai import OpenAI
#       3 llm = OpenAI(model="gpt-4o-mini", api_key="paste-your-actual-key-here")
# ----> 5 response = llm.complete("Say hello in one short sentence.")
#       6 print(response)
#
# File ~\anaconda3\envs\llamaindex310\lib\site-packages\llama_index_instrumentation\dispatcher.py:413, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     410             _logger.debug(f"Failed to reset active_span_id: {e}")
#     412 try:
# --> 413     result = func(*args, **kwargs)
#     414     if isinstance(result, asyncio.Future):
#     415         # If the result is a Future, wrap it
#     416         new_future = asyncio.ensure_future(result)
#
# ...

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-4o-mini", api_key="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")

response = llm.complete("Say hello in one short sentence.")
print(response)
# Out:
# Retrying llama_index.llms.openai.base.OpenAI._chat in 1 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# Retrying llama_index.llms.openai.base.OpenAI._chat in 1.77 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 5
# ...

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="llama3.2", request_timeout=120.0)

response = llm.complete("Say hello in one short sentence.")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[6], line 5
#       1 from llama_index.llms.ollama import Ollama
#       3 llm = Ollama(model="llama3.2", request_timeout=120.0)
# ----> 5 response = llm.complete("Say hello in one short sentence.")
#       6 print(response)
#
# File ~\anaconda3\envs\llamaindex310\lib\site-packages\llama_index_instrumentation\dispatcher.py:413, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     410             _logger.debug(f"Failed to reset active_span_id: {e}")
#     412 try:
# --> 413     result = func(*args, **kwargs)
#     414     if isinstance(result, asyncio.Future):
#     415         # If the result is a Future, wrap it
#     416         new_future = asyncio.ensure_future(result)
#
# ...

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="qwen2.5:0.5b", request_timeout=120.0)

response = llm.complete("Say hello in one short sentence.")
print(response)
# Out:
# Hello! It's a pleasure to meet you.

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="qwen2.5:0.5b", request_timeout=120.0)

response = llm.complete("Write a 1-line summary of artificial intelligence.")
print(response)
# Out:
# Artificial intelligence is the simulation of human intelligence and reasoning processes by computer systems.

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="qwen2.5:0.5b", request_timeout=120.0)

def ask_llm(prompt):
    response = llm.complete(prompt)
    return str(response)

print(ask_llm("Give me one short resume-friendly project description for a local AI assistant."))
# Out:
# Certainly! Here's a short, concise resume-friendly project description for a local AI assistant:
#
# AI Assistant: A Personal Assistant for Home and Work, Local AI Assistant
#
# Overview:
# The AI assistant, a personal assistant for home and work, is designed to provide a seamless, intuitive experience through natural language processing. The AI assistant offers features such as task automation, task delegation, and personalized recommendations, all made simple and user-friendly.
#
# Responsibilities:
# - Task automation: Automate various household chores and tasks using AI algorithms.
# - Task delegation: Delegate tasks to the AI assistant based on the tasks' importance and urgency.
# - Personalized recommendations: Offer personalized insights and suggestions based on user's activities and preferences.
#
# Tools:
# - Google Assistant Integration: Seamless integration with Google Assistant for voice-activated tasks and personalized recommendations.
# ...

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="qwen2.5:0.5b", request_timeout=120.0)

project_prompt = """
Write 3 concise resume bullet points for a project where I built
a local AI assistant in Python using LlamaIndex and Ollama.
Keep each bullet strong, simple, and beginner-friendly.
"""

response = llm.complete(project_prompt)
print(response)
# Out:
# 1. I built a local AI assistant in Python using LlamaIndex and Ollama, which is an AI assistant for Python.
# 2. LlamaIndex is a large language model that helps AI assistants understand and generate human-like text.
# 3. Ollama is another AI assistant that provides information and solutions to help users with their tasks.

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="qwen2.5:0.5b", request_timeout=120.0)

while True:
    user_input = input("You: ")
    
    if user_input.lower() in ["exit", "quit"]:
        print("Assistant: Goodbye!")
        break
    
    response = llm.complete(user_input)
    print("Assistant:", response)
# Out:
# You: exit
# Assistant: Goodbye!

# %%
chatbot_code = '''
from llama_index.llms.ollama import Ollama

llm = Ollama(model="qwen2.5:0.5b", request_timeout=120.0)

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Assistant: Goodbye!")
        break

    response = llm.complete(user_input)
    print("Assistant:", response)
'''

with open("local_ai_assistant.py", "w", encoding="utf-8") as f:
    f.write(chatbot_code)

print("Saved as local_ai_assistant.py")
# Out:
# Saved as local_ai_assistant.py

# %%
import os
print(os.path.abspath("local_ai_assistant.py"))
print(os.path.exists("local_ai_assistant.py"))
# Out:
# C:\Users\nisarg\local_ai_assistant.py
# True

# %%
with open("local_ai_assistant.py", "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# from llama_index.llms.ollama import Ollama
#
# llm = Ollama(model="qwen2.5:0.5b", request_timeout=120.0)
#
# while True:
#     user_input = input("You: ")
#
#     if user_input.lower() in ["exit", "quit"]:
#         print("Assistant: Goodbye!")
#         break
#
#     response = llm.complete(user_input)
#     print("Assistant:", response)

# %%
# !python local_ai_assistant.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\nisarg\local_ai_assistant.py", line 2, in <module>
#     from llama_index.llms.ollama import Ollama
# ModuleNotFoundError: No module named 'llama_index.llms.ollama'

# %%
import sys
print(sys.executable)

# %%
import sys
!"{sys.executable}" local_ai_assistant.py

# %%
# %pip install tavily-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tavily import AsyncTavilyClient


async def search_web(query: str) -> str:
    """Useful for using the web to answer questions."""
    client = AsyncTavilyClient(api_key="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")
    return str(await client.search(query))

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="qwen2.5:0.5b", request_timeout=120.0)

# %%
from llama_index.core.agent.workflow import FunctionAgent

agent = FunctionAgent(
    tools=[search_web],
    llm=llm,
    system_prompt="You are a helpful assistant that can search the web for information.",
)

# %%
print(agent)
# Out:
# name='Agent' description='An agent that can perform a task' system_prompt='You are a helpful assistant that can search the web for information.' tools=[<llama_index.core.tools.function_tool.FunctionTool object at 0x0000024997A30F70>] tool_retriever=None can_handoff_to=None llm=Ollama(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x000002499883CD00>, rate_limiter=None, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x00000249FEA063B0>, completion_to_prompt=<function default_completion_to_prompt at 0x00000249FED4F010>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, base_url='http://localhost:11434', model='qwen2.5:0.5b', temperature=None, context_window=-1, request_timeout=120.0, prompt_key='prompt', json_mode=False, additional_kwargs={}, is_function_calling_model=True, keep_alive=None, thinking=None) initial_state={} state_prompt='Current state:\n{state}\n\nCurrent mes
# ...

# %%
response = await agent.run("What is Python?")
print(response)
# Out:
# Python is a high-level, interpreted programming language developed by Guido van Rossum and first released in 1991. It is known for its simplicity and readability, making it particularly useful for beginners. Python is often used for data analysis, web development, artificial intelligence, machine learning, and many other applications. It runs on multiple platforms, including Windows, macOS, and Linux.

# %%
response = await agent.run("Search the web for the official Python website and tell me its URL.")
print(response)
# Out:
# The official Python website URL is: <tool_response>

# %%
result = await search_web("official Python website")
print(result)
# Out:
# {'query': 'official Python website', 'response_time': 0.79, 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.python.org/', 'title': 'Welcome to Python.org', 'content': "More about defining functions in Python\xa03. Lists (known as arrays in other languages) are one of the compound data types that Python understands. More about lists in Python\xa03. More about simple math functions in Python\xa03. More control flow tools in Python\xa03. Experienced programmers in any other language can pick up Python very quickly, and beginners find the clean syntax and indentation structure easy to learn. Python is a programming language that lets you work quickly and integrate systems more effectively. Whether you're new to programming or an experienced developer, it's easy to learn and use Python. Python source code and installers are available for download for all versions! Latest: Python 3.14.3. * Python 3.12.13, 3.11.15 and 3.10.20 are now available! ##
# ...

# %%
result = await search_web("official Python website")
print(result)
# Out:
# {'query': 'official Python website', 'response_time': 0.79, 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.python.org/', 'title': 'Welcome to Python.org', 'content': "More about defining functions in Python\xa03. Lists (known as arrays in other languages) are one of the compound data types that Python understands. More about lists in Python\xa03. More about simple math functions in Python\xa03. More control flow tools in Python\xa03. Experienced programmers in any other language can pick up Python very quickly, and beginners find the clean syntax and indentation structure easy to learn. Python is a programming language that lets you work quickly and integrate systems more effectively. Whether you're new to programming or an experienced developer, it's easy to learn and use Python. Python source code and installers are available for download for all versions! Latest: Python 3.14.3. * Python 3.12.13, 3.11.15 and 3.10.20 are now available! ##
# ...

# %%
response = await agent.run("Search the web for the official Python website and tell me its URL.")
print(response)
# Out:
# The official Python website is https://www.python.org/ . You can find more information about it at the URL provided.

# %%
response = await agent.run(user_msg="What is the weather in San Francisco?")
print(str(response))
# Out:
# The weather in San Francisco is partly cloudy with a temperature of 17.2°C (63.0°F) in the morning and 17.2°C (63.0°F) in the evening. The probability of precipitation is around 557%. There will be no snow, and the highest temperature will be around 11.7°C (53.0°F) in the morning. The wind will be blowing from the southwest at 11.4 mph. The weather forecast for March 11, 2026, is as follows:
#
# - **Temperature:** 11.7°C (53.0°F)
# - **Feels like:** 17.2°C (63.0°F)
# - **Rainfall:** 0.0 mm
# - **Precipitation:** 557%, Wind: 11 km/h, N
#
# The wind will blow from the southwest at 11.4 mph and there will be no snow, so you can enjoy the sunny days in San Francisco during March 11, 2026.

# %%
from llama_index.core.agent.workflow import AgentWorkflow

workflow = AgentWorkflow(agents=[agent])

response = await workflow.run(user_msg="What is the weather in San Francisco?")

# %%
from llama_index.core.workflow import Context

ctx = Context(agent)

# %%
response = await agent.run(
    user_msg="My name is Logan, nice to meet you!", ctx=ctx
)
print(str(response))
# Out:
# Hello Logan! How can I assist you today?

# %%
response = await agent.run(user_msg="What is my name?", ctx=ctx)
print(str(response))
# Out:
# Your name is Logan. How can I help you today?

# %%
from llama_index.core.workflow import JsonPickleSerializer, JsonSerializer

ctx_dict = ctx.to_dict(serializer=JsonSerializer())

restored_ctx = Context.from_dict(agent, ctx_dict, serializer=JsonSerializer())

# %%
response = await agent.run(
    user_msg="Do you still remember my name?", ctx=restored_ctx
)
print(str(response))
# Out:
# Yes, I do. How can I assist you today?

# %%
from llama_index.core.agent.workflow import (
    AgentInput,
    AgentOutput,
    ToolCall,
    ToolCallResult,
    AgentStream,
)

handler = agent.run(user_msg="What is the weather in Saskatoon?")

async for event in handler.stream_events():
    if isinstance(event, AgentStream):
        print(event.delta, end="", flush=True)
        # print(event.response)  # the current full response
        # print(event.raw)  # the raw llm api response
        # print(event.current_agent_name)  # the current agent name
    # elif isinstance(event, AgentInput):
    #    print(event.input)  # the current input messages
    #    print(event.current_agent_name)  # the current agent name
    # elif isinstance(event, AgentOutput):
    #    print(event.response)  # the current full response
    #    print(event.tool_calls)  # the selected tool calls, if any
    #    print(event.raw)  # the raw llm api response
    # elif isinstance(event, ToolCallResult):
    #    print(event.tool_name)  # the tool name
    #    print(event.tool_kwargs)  # the tool kwargs
    #    print(event.tool_output)  # the tool output
    # elif isinstance(event, ToolCall):
    #     print(event.tool_name)  # the tool name
    #     print(event.tool_kwargs)  # the tool kwargs
# Out:
# The current weather in Saskatoon is -9.6°C and -11.9°C. The temperature range is from -15.2°C to 28.0°C. The wind speed is moderate, averaging 4.5 mph. The wind direction is NE. The weather in Saskatoon has been stable for the past few days. If you need more detailed information, you can check the [Weather25 website](https://www.weather25.com/north-america/canada/saskatchewan/saskatoon) or the [Easeweather website](https://www.easeweather.com/north-america/canada/saskatchewan/saskatoon/march).

# %%
from llama_index.core.workflow import Context


async def set_name(ctx: Context, name: str) -> str:
    async with ctx.store.edit_state() as ctx_state:
        ctx_state["state"]["name"] = name
    return f"Name set to {name}"


agent = FunctionAgent(
    tools=[set_name],
    llm=llm,
    system_prompt="You are a helpful assistant that can set a name.",
    initial_state={"name": "unset"},
)

ctx = Context(agent)

response = await agent.run(user_msg="My name is Logan", ctx=ctx)
print(str(response))

state = await ctx.store.get("state")
print(state["name"])
# Out:
# Your name is now set to "unset". How can I assist you?
# unset

# %%
from llama_index.core.workflow import (
    Context,
    InputRequiredEvent,
    HumanResponseEvent,
)


async def dangerous_task(ctx: Context) -> str:
    """A dangerous task that requires human confirmation."""

    question = "Are you sure you want to proceed?"
    response = await ctx.wait_for_event(
        HumanResponseEvent,
        waiter_id=question,
        waiter_event=InputRequiredEvent(
            prefix=question,
            user_name="Logan",
        ),
        requirements={"user_name": "Logan"},
    )
    if response.response == "yes":
        return "Dangerous task completed successfully."
    else:
        return "Dangerous task aborted."


agent = FunctionAgent(
    tools=[dangerous_task],
    llm=llm,
    system_prompt="You are a helpful assistant that can perform dangerous tasks.",
)

# %%
handler = agent.run(user_msg="I want to proceed with the dangerous task.")

async for event in handler.stream_events():
    if isinstance(event, InputRequiredEvent):
        response = input(event.prefix).strip().lower()
        handler.ctx.send_event(
            HumanResponseEvent(
                response=response,
                user_name=event.user_name,
            )
        )

response = await handler
print(str(response))
# Out:
# Sure, I can help you with the dangerous task. Please provide the details of the task so I can proceed with it.

# %%
from llama_index.core.workflow import JsonSerializer

handler = agent.run(user_msg="I want to proceed with the dangerous task.")

input_ev = None
async for event in handler.stream_events():
    if isinstance(event, InputRequiredEvent):
        input_ev = event
        break

# save the context somewhere for later
ctx_dict = handler.ctx.to_dict(serializer=JsonSerializer())

# get the response from the user
response_str = input(input_ev.prefix).strip().lower()

# restore the workflow
restored_ctx = Context.from_dict(agent, ctx_dict, serializer=JsonSerializer())

handler = agent.run(ctx=restored_ctx)
handler.ctx.send_event(
    HumanResponseEvent(
        response=response_str,
        user_name=input_ev.user_name,
    )
)
response = await handler
print(str(response))
# Out:
# Are you sure you want to proceed?Yes
# Congratulations! The task has been completed successfully.
